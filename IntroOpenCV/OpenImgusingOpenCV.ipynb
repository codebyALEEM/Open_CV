# %% [markdown]
# OPEN IMAGE WITH OPENCV WITHOUT USING MATPLOTLIB

# %%
import cv2 

myimg = cv2.imread(r'C:\Users\VICTUS\Desktop\royce.jpg')

cv2.imshow('nit',myimg)

cv2.waitKey()
# Out:
# -1

# %%
import cv2 

myimg = cv2.imread(r'C:\Users\VICTUS\Desktop\royce.jpg')

while True:
    cv2.imshow('royce',myimg)
    if cv2.waitKey(1) & 0XFF == 27:
        break
    
cv2.destroyAllWindows()
