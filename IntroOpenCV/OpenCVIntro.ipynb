# %% [markdown]
# OPENCV AND IMAGE PROCESSING

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\VICTUS\Desktop\cat2.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img =  cv2.imread(r"C:\Users\VICTUS\Desktop\royce.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (414, 736, 3)

# %%
img
# Out:
# array([[[72, 45, 18],
#         [72, 45, 18],
#         [72, 45, 18],
#         ...,
#         [40, 20,  3],
#         [40, 20,  3],
#         [40, 20,  3]],
#
#        [[72, 45, 18],
#         [72, 45, 18],
#         [72, 45, 18],
#         ...,
#         [40, 20,  3],
#         [40, 20,  3],
#         [40, 20,  3]],
#
#        [[73, 46, 19],
#         [73, 46, 19],
#         [73, 46, 19],
#         ...,
#         [40, 20,  3],
#         [40, 20,  3],
#         [40, 20,  3]],
#
#        ...,
#
#        [[47, 24,  8],
#         [48, 25,  9],
#         [48, 25,  9],
#         ...,
#         [40, 20,  3],
#         [40, 20,  3],
#         [40, 20,  3]],
#
#        [[47, 24,  8],
#         [47, 24,  8],
#         [47, 24,  8],
#         ...,
#         [40, 20,  3],
#         [40, 20,  3],
#         [40, 20,  3]],
#
#        [[47, 24,  8],
#         [47, 24,  8],
#         [47, 24,  8],
#         ...,
#         [40, 20,  3],
#         [40, 20,  3],
# ...

# %% [markdown]
# - matplotlibe channel--> Always give the channel ( R G B) || red, green, blue
# - opencv channel --> (B G R) || blue , green , red

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\VICTUS\Desktop\royce.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape  # it dont have 3 channel now as before
# Out:
# (414, 736)

# %%
img_gray
# Out:
# array([[40, 40, 40, ..., 17, 17, 17],
#        [40, 40, 40, ..., 17, 17, 17],
#        [41, 41, 41, ..., 17, 17, 17],
#        ...,
#        [22, 23, 23, ..., 17, 17, 17],
#        [22, 22, 22, ..., 17, 17, 17],
#        [22, 22, 22, ..., 17, 17, 17]], shape=(414, 736), dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
plt.imshow(img_gray,cmap='Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (414, 736, 3)

# %%
fix_img1 = cv2.resize(fix_img,(800,600))

# %%
plt.imshow(fix_img1)

# %%
fix_img.shape
# Out:
# (414, 736, 3)

# %%
w_ratio =0.3
h_ratio =0.3

# %%
fix_img2 = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img2.shape
# Out:
# (124, 221, 3)

# %%
img3 = cv2.flip(fix_img2,0)

# %%
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img2,0)
plt.imshow(img3)

# %%
cv2.imwrite("New Generated Img.jpg",img3)
# Out:
# True
