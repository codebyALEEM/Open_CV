# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r'C:\Users\VICTUS\Desktop\e1.webp')

# %%
input
# Out:
# array([[[ 44,  43,   4],
#         [ 44,  43,   4],
#         [ 42,  43,   4],
#         ...,
#         [ 61,  80,  45],
#         [ 60,  77,  40],
#         [ 58,  75,  38]],
#
#        [[ 42,  43,   4],
#         [ 41,  45,   5],
#         [ 39,  45,   5],
#         ...,
#         [ 61,  80,  45],
#         [ 60,  79,  44],
#         [ 59,  78,  43]],
#
#        [[ 40,  48,  11],
#         [ 39,  50,  12],
#         [ 43,  53,  15],
#         ...,
#         [ 58,  79,  44],
#         [ 58,  79,  44],
#         [ 57,  77,  44]],
#
#        ...,
#
#        [[ 10, 156,  96],
#         [ 17, 160, 100],
#         [ 16, 159,  99],
#         ...,
#         [ 70, 106,  73],
#         [ 74, 112,  76],
#         [ 71, 108,  72]],
#
#        [[  9, 147,  89],
#         [ 16, 154,  96],
#         [ 11, 151,  92],
#         ...,
#         [ 67, 104,  71],
#         [ 70, 107,  71],
#         [ 69, 106,  70]],
#
#        [[  9, 140,  83],
#         [ 13, 147,  89],
#         [  8, 146,  87],
# ...

# %%
cv2.imshow('e1',input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('Height of Image:',int(input.shape[0]),'pixels')
print('Width of Image:',int(input.shape[1]),'pixels')
# Out:
# Height of Image: 399 pixels
# Width of Image: 600 pixels

# %%
cv2.imwrite('e1.webp',input)
# Out:
# True
